# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/Fingerprint GANs/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Fingerprint GANs

# %%
# !git clone https://github.com/mehmetaydar/fingerprint-alignment
# Out:
# Cloning into 'fingerprint-alignment'...
# remote: Enumerating objects: 55, done.
# remote: Total 55 (delta 0), reused 0 (delta 0), pack-reused 55
# Unpacking objects: 100% (55/55), done.

# %%
# %cd fingerprint-alignment/
# Out:
# /content/gdrive/My Drive/Fingerprint GANs/fingerprint-alignment

# %%
import matplotlib
matplotlib.use('TKAgg')

import matplotlib.pyplot as plt

# %%
# !python mextract.py images/103_1.tif 1 16 --preprocess --smooth --save
# Out:
# Block-size:  16
# image:  ('images/103_1', '.tif')
# image enhanced:  images/103_1_enhanced_thinned.gif
# Enhanced image does not exists. Enhancing.
# Gabor filtering and thinning ...
# calculating orientation done
# smoothing angles done
# Traceback (most recent call last):
#   File "mextract.py", line 537, in <module>
#     main2()
#   File "mextract.py", line 478, in main2
#     im = gabor(im, W, angles)
#   File "mextract.py", line 34, in gabor
#     freqs = frequency.freq(im, W, angles)
#   File "/content/gdrive/My Drive/Fingerprint GANs/fingerprint-alignment/frequency.py", line 82, in freq
#     freq = block_frequency(i, j, W, angles[i][j], im_load)
#   File "/content/gdrive/My Drive/Fingerprint GANs/fingerprint-alignment/frequency.py", line 49, in block_frequency
#     points = points_on_line(line, W)
#   File "/content/gdrive/My Drive/Fingerprint GANs/fingerprint-alignment/frequency.py", line 27, in points_on_line
# ...

# %%
matplotlib.use('WebAgg')
